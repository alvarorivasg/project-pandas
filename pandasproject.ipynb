# %%
import pandas as pd
import re

# %%
#pasarán muchas, muchas celdas hasta que algo de lo que haga tenga sentido. Me limitaré en primer lugar a 
#familiarizarme con apply y con otros métodos de Pandas, limitándome a realizar pequeños cambios en las columnas.
#Recomendación para el TA: corregir sólo las celdas con comentario, pues sólo en ellas traté de hacer cosas serias
data=pd.read_csv("input/GSAF5.csv",engine='python')
null_cols = data.isnull().sum()
print(null_cols)
print(len(data.index))
print((data==0).sum())
nombresex=data[['Name','Sex ']]
data=data.rename(columns={'Species ': 'Species','Sex ': 'Sex'})
data=data.drop(columns='Unnamed: 22')
data=data.drop(columns='Unnamed: 23')
data.columns
# Out:
# Case Number                  0
# Date                         0
# Year                         0
# Type                         0
# Country                     43
# Area                       402
# Location                   496
# Activity                   527
# Name                       200
# Sex                        567
# Age                       2681
# Injury                      27
# Fatal (Y/N)                 19
# Time                      3213
# Species                   2934
# Investigator or Source      15
# pdf                          0
# href formula                 1
# href                         3
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               5991
# Unnamed: 23               5990
# dtype: int64
# 5992
# Case Number                 0
# Date                        0
# Year                      124
# Type                        0
# Country                     0
# ...

# %%
data1 = data[(data['Country']=='SPAIN')]
data1
# Out:
#        Case Number                  Date  Year        Type Country  \
# 20      2016.07.29             29-Jul-16  2016  Unprovoked   SPAIN
# 34    2016.07.08.R  Reported 08-Jul-2016  2016  Unprovoked   SPAIN
# 104     2015.12.25             25-Dec-15  2015  Unprovoked   SPAIN
# 159   2015.08.18.a             18-Aug-15  2015     Invalid   SPAIN
# 249   2014.12.03.R  Reported 03-Dec-2014  2014    Provoked   SPAIN
# 282     2014.09.00                Sep-14  2014  Unprovoked   SPAIN
# 287   2014.08.27.c             27-Aug-14  2014  Unprovoked   SPAIN
# 307     2014.07.20             20-Jul-14  2014  Unprovoked   SPAIN
# 434     2013.07.09             07-Jul-13  2013     Invalid   SPAIN
# 788   2010.07.16.b             16-Jul-10  2010    Provoked   SPAIN
# 884   2009.07.24.a             24-Jul-09  2009     Invalid   SPAIN
# 1234    2006.07.13             13-Jul-06  2006     Invalid   SPAIN
# 2251    1993.09.03             03-Sep-93  1993  Unprovoked   SPAIN
# ...

# %%
data.dtypes
# Out:
# Case Number               object
# Date                      object
# Year                       int64
# Type                      object
# Country                   object
# Area                      object
# Location                  object
# Activity                  object
# Name                      object
# Sex                       object
# Age                       object
# Injury                    object
# Fatal (Y/N)               object
# Time                      object
# Species                   object
# Investigator or Source    object
# pdf                       object
# href formula              object
# href                      object
# Case Number.1             object
# Case Number.2             object
# original order             int64
# dtype: object

# %%
lista=list(data)

# %%
print((data==0).sum())
# Out:
# Case Number                 0
# Date                        0
# Year                      124
# Type                        0
# Country                     0
# Area                        0
# Location                    0
# Activity                    0
# Name                        0
# Sex                         0
# Age                         0
# Injury                      0
# Fatal (Y/N)                 0
# Time                        0
# Species                     0
# Investigator or Source      0
# pdf                         0
# href formula                0
# href                        0
# Case Number.1               0
# Case Number.2               0
# original order              0
# dtype: int64

# %%
data[lista]
# Out:
#        Case Number         Date  Year        Type             Country  \
# 0     2016.09.18.c    18-Sep-16  2016  Unprovoked                 USA
# 1     2016.09.18.b    18-Sep-16  2016  Unprovoked                 USA
# 2     2016.09.18.a    18-Sep-16  2016  Unprovoked                 USA
# 3       2016.09.17    17-Sep-16  2016  Unprovoked           AUSTRALIA
# 4       2016.09.15    16-Sep-16  2016  Unprovoked           AUSTRALIA
# ...            ...          ...   ...         ...                 ...
# 5987       ND.0005  Before 1903     0  Unprovoked           AUSTRALIA
# 5988       ND.0004  Before 1903     0  Unprovoked           AUSTRALIA
# 5989       ND.0003    1900-1905     0  Unprovoked                 USA
# 5990       ND.0002    1883-1889     0  Unprovoked              PANAMA
# 5991       ND.0001    1845-1853     0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
valuesex=set(data['Sex'])
valuesex
# Out:
# {'.', 'F', 'M', 'M ', 'N', 'lli', nan}

# %%
#tratando de entender apply
def hombres(m):
    if m['Sex']=='M ':
        return 'M'
    else:
        return m

# %%
dataapplied=data.apply(hombres,axis=1)
dataapplied
# Out:
#        Case Number         Date  Year        Type             Country  \
# 0     2016.09.18.c    18-Sep-16  2016  Unprovoked                 USA
# 1     2016.09.18.b    18-Sep-16  2016  Unprovoked                 USA
# 2     2016.09.18.a    18-Sep-16  2016  Unprovoked                 USA
# 3       2016.09.17    17-Sep-16  2016  Unprovoked           AUSTRALIA
# 4       2016.09.15    16-Sep-16  2016  Unprovoked           AUSTRALIA
# ...            ...          ...   ...         ...                 ...
# 5987       ND.0005  Before 1903     0  Unprovoked           AUSTRALIA
# 5988       ND.0004  Before 1903     0  Unprovoked           AUSTRALIA
# 5989       ND.0003    1900-1905     0  Unprovoked                 USA
# 5990       ND.0002    1883-1889     0  Unprovoked              PANAMA
# 5991       ND.0001    1845-1853     0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
valuesex1=set(dataapplied['Sex'])
valuesex1
# Out:
# {'.', 'F', 'M', 'N', 'lli', nan}

# %%
cuantos=dataapplied['Sex'].value_counts(dropna=False)
cuantos
# Out:
# M      4837
# F       585
# NaN     567
# .         1
# N         1
# lli       1
# Name: Sex, dtype: int64

# %%
averbro = dataapplied[(dataapplied['Sex']=='N')]
averbro
# Out:
#      Case Number       Date  Year     Type    Country             Area  \
# 4708  1934.07.11  11-Jul-34  1934  Boating  AUSTRALIA  New South Wales
#
#       Location Activity                                         Name Sex  ...  \
# 4708  Cronulla  Fishing  18' boat, occupants William & Leslie Newton   N  ...
#
#      Fatal (Y/N) Time             Species  \
# 4708           N  NaN  Blue pointer, 11'
#
#                                  Investigator or Source  \
# 4708  G.P. Whitley, ref: Daily Telegraph, 7/11/1934 ...
#
#                                        pdf  \
# 4708  1934.07.11-Newton-boat-Australia.pdf
#
#                                            href formula  \
# 4708  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 4708  http://sharkattackfile.net/spreadsheets/pdf_di...    1934.07.11
#
#      Case Number.2 original order
# 4708    1934.07.11           1285
#
# [1 rows x 22 columns]

# %%
#probando apply. Parece que el argumento que recibe la función, cuando axis=1, es toda la fila (de primeras puede
#resultar contraintuitivo)
def hombres1(m):
    if m['Sex']=='lli':
        return 'M'
    else:
        return m

# %%
dataapplied1=dataapplied1.apply(hombres1,axis=1)
dataapplied1
# Out:
#        Case Number         Date  Year        Type             Country  \
# 0     2016.09.18.c    18-Sep-16  2016  Unprovoked                 USA
# 1     2016.09.18.b    18-Sep-16  2016  Unprovoked                 USA
# 2     2016.09.18.a    18-Sep-16  2016  Unprovoked                 USA
# 3       2016.09.17    17-Sep-16  2016  Unprovoked           AUSTRALIA
# 4       2016.09.15    16-Sep-16  2016  Unprovoked           AUSTRALIA
# ...            ...          ...   ...         ...                 ...
# 5987       ND.0005  Before 1903     0  Unprovoked           AUSTRALIA
# 5988       ND.0004  Before 1903     0  Unprovoked           AUSTRALIA
# 5989       ND.0003    1900-1905     0  Unprovoked                 USA
# 5990       ND.0002    1883-1889     0  Unprovoked              PANAMA
# 5991       ND.0001    1845-1853     0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
cuantos=dataapplied1['Sex'].value_counts(dropna=False)
cuantos
datadom=dataapplied1

# %%
dataapplied1.loc[4708,"href formula"]
# Out:
# 'http://sharkattackfile.net/spreadsheets/pdf_directory/1934.07.11-Newton-boat-Australia.pdf'

# %%
#datawow=dataapplied1.drop(4708,axis=0)

# %%
#la cagué continuamente al ejecutar en varias ocasiones celdas que no correspondían, luego los nombres del 
#dataframe (dataseda, datawow, datadom...) varían sin lógica aparente.

# %%
averbro = dataseda[(dataseda['Sex']=='.')]
averbro
# Out:
# Empty DataFrame
# Columns: [Case Number, Date, Year, Type, Country, Area, Location, Activity, Name, Sex, Age, Injury, Fatal (Y/N), Time, Species, Investigator or Source, pdf, href formula, href, Case Number.1, Case Number.2, original order]
# Index: []
#
# [0 rows x 22 columns]

# %%
#datawow=datawow.drop(5201,axis=0)

# %%
cuantos=dataseda['Sex'].value_counts(dropna=False)
cuantos
# Out:
# M      4838
# F       585
# NaN     567
# Name: Sex, dtype: int64

# %%
cuantos=dataseda['Age'].value_counts(dropna=False)
cuantos
# Out:
# NaN        2678
# 17          148
# 18          145
# 19          138
# 20          136
#            ...
# 30 & 32       1
# 33 & 37       1
# 36 & 23       1
# 46 & 34       1
# 17 & 16       1
# Name: Age, Length: 152, dtype: int64

# %%
cuantos=dataseda['Species'].value_counts(dropna=False)
cuantos
# Out:
# NaN                                           2933
# White shark                                    161
# Shark involvement not confirmed                 80
# Tiger shark                                     68
# Bull shark                                      52
#                                               ...
# Tiger shark, 12                                  1
# Blacktip or spinner shark, 4'                    1
# Bronze whaler shark, 4'                          1
# 1.2 m to 1.5 m [4' to 5'] hammerhead shark       1
# 3.7m  to 4.2 m white shark                       1
# Name: Species, Length: 1538, dtype: int64

# %%
dataseda=dataseda.drop_duplicates()
dataseda
# Out:
#        Case Number         Date  Year        Type             Country  \
# 0     2016.09.18.c    18-Sep-16  2016  Unprovoked                 USA
# 1     2016.09.18.b    18-Sep-16  2016  Unprovoked                 USA
# 2     2016.09.18.a    18-Sep-16  2016  Unprovoked                 USA
# 3       2016.09.17    17-Sep-16  2016  Unprovoked           AUSTRALIA
# 4       2016.09.15    16-Sep-16  2016  Unprovoked           AUSTRALIA
# ...            ...          ...   ...         ...                 ...
# 5987       ND.0005  Before 1903     0  Unprovoked           AUSTRALIA
# 5988       ND.0004  Before 1903     0  Unprovoked           AUSTRALIA
# 5989       ND.0003    1900-1905     0  Unprovoked                 USA
# 5990       ND.0002    1883-1889     0  Unprovoked              PANAMA
# 5991       ND.0001    1845-1853     0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
cuantos=dataseda['Country'].value_counts(dropna=False)
cuantos
# Out:
# USA                         2114
# AUSTRALIA                   1277
# SOUTH AFRICA                 565
# PAPUA NEW GUINEA             132
# NEW ZEALAND                  125
#                             ...
# DJIBOUTI                       1
# ANGOLA                         1
# NORTHERN MARIANA ISLANDS       1
# Sierra Leone                   1
# GABON                          1
# Name: Country, Length: 205, dtype: int64

# %%
lol=dataseda['Case Number'].str.len==1
lol
# Out:
# False

# %%
momento=dataseda['Time'].value_counts()
momento
# Out:
# Unknown          3210
# Morning           415
# Afternoon         174
# 12h00             107
# 15h00             100
#                  ...
# 19h00 / 20h00       1
# 02h45               1
# 11h25               1
# 15h53               1
# 12h34               1
# Name: Time, Length: 332, dtype: int64

# %%
datadom['Time']=datadom['Time'].fillna('Unknown')

# %%
momento=dataapplied1['Time'].value_counts()
momento
# Out:
# Unknown             3212
# Afternoon            174
# 11h00                123
# Morning              107
# 12h00                107
#                     ...
# 18h12                  1
# 19h55                  1
# Just after 12h00       1
# Early Morning          1
# 12h34                  1
# Name: Time, Length: 359, dtype: int64

# %%
datadom
# Out:
#        Case Number         Date  Year        Type             Country  \
# 0     2016.09.18.c    18-Sep-16  2016  Unprovoked                 USA
# 1     2016.09.18.b    18-Sep-16  2016  Unprovoked                 USA
# 2     2016.09.18.a    18-Sep-16  2016  Unprovoked                 USA
# 3       2016.09.17    17-Sep-16  2016  Unprovoked           AUSTRALIA
# 4       2016.09.15    16-Sep-16  2016  Unprovoked           AUSTRALIA
# ...            ...          ...   ...         ...                 ...
# 5987       ND.0005  Before 1903     0  Unprovoked           AUSTRALIA
# 5988       ND.0004  Before 1903     0  Unprovoked           AUSTRALIA
# 5989       ND.0003    1900-1905     0  Unprovoked                 USA
# 5990       ND.0002    1883-1889     0  Unprovoked              PANAMA
# 5991       ND.0001    1845-1853     0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
#tratando de meter el bisturí en el dataframe sin recurrir a .apply. Trasteando con las horas
#conseguí modificarlo pero la cagué al ejecutar celdas superiores
#he dejado escritas las celdas que en algún momento tuvieron sentido. Por ejemplo, este loop for 
#me devolvió en algún punto más de 400 valores en "Morning". Ahora no sé qué diablos pasa
for i in range(0,len(datadom['Time'])):
    t=datadom['Time'][i]
    if re.search('\d\d+',t):
        if '05'<=t[0:3]<'12':
            datadom['Time'][i]=='Morning'
          
        elif '12'<=t[0:3]<'17':
            datadom['Time'][i]=='Afternoon'
          
        elif '17'<=t[0:3]<'22':
            datadom['Time'][i]=='Evening'
           
        elif '22'<=t[0:3]<'24' or t[0:3]<'05':
            datadom['Time'][i]=='Night'

# %%
#no sé qué diablos sale mal. Veo que muchísimas horas no son capturadas por mis if y elif

# %%
momento=datadom['Time'].value_counts()
momento
# Out:
# Unknown             3212
# Afternoon            174
# 11h00                123
# Morning              107
# 12h00                107
#                     ...
# 18h12                  1
# 19h55                  1
# Just after 12h00       1
# Early Morning          1
# 12h34                  1
# Name: Time, Length: 359, dtype: int64

# %%
#He abandonado todo propósito de hallar algo convincente. He buceado en los commit de mis compañeros y,
#salvo algún fuera de serie, he visto que muchos optan por ir eliminando valores vacíos hasta poder responder
#a alguna pregunta. Prefiero trastear con Pandas; discúlpame, oh TA, si mi ejercicio es incorregible.
#Ahora me gustaría rellenar la columna Year de aquellas filas que tienen Year==0 pero contienen en 'Date' una cifra
#de cuatro dígitos (que corresponde, me figuro, al año del ataque)

# %%
#la lógica sería así: para cada string de la columna Date, con un findall cazo la cifra, y la meto a la columna
#Year si ésta está vacía

# %%
lista=[i for i in yesdata['Date']]
string = ' '.join(lista)

# %%
#queda comprobado que, de escribir el código correctamente, podré trabajar con ello
x=re.findall('\d{4}',string)
x
# Out:
# ['2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2015',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2012',
#  '2012',
#  '2012',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2010',
#  '2011',
#  '2011',
#  '2011',
#  '2010',
#  '2010',
#  '2010',
#  '2010',
#  '2010',
#  '2010',
#  '2010',
#  '2010',
#  '2010',
#  '2010',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
# ...

# %%
#no sé si valdrá. Upd: no valió
def fillyear(columndate):
    for i in df['Date']:
        x=re.findall('\d{4}',i)
        if len(x)==1:
            w=x[0]
            if df['Year']==0:
                return df['Year']==w
            else: pass
        else:
            pass

# %%
#incorrecto, ya que voy a hacer apply sobre una serie y no es necesario el loop
def extractyear(column):
    for i in column:
        x=re.findall('\d{4}',i)
        if len(x)==1:
            w=x[0]
            return w
        else: return 'lol'

# %%
def extractyear1(column):
    x=re.findall('\d{4}',column)
    if len(x)==1:
        w=x[0]
        return w
    else: return 0

# %%
#voy a comenzar de nuevo mi análisis de los datos, aplicando esta función
yesdata=pd.read_csv("input/GSAF5.csv",engine='python')
yesdata.head()
# Out:
#     Case Number       Date  Year        Type    Country      Area  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked        USA   Florida
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked        USA   Florida
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked        USA   Florida
# 3    2016.09.17  17-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
# 4    2016.09.15  16-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location Activity             Name Sex   ...  \
# 0  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 1  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano    M  ...
# 2  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 3                  Thirteenth Beach  Surfing  Rory Angiolella    M  ...
# 4                       Bells Beach  Surfing             male    M  ...
#
#     Species        Investigator or Source                        pdf  \
# ...

# %%
yesdata['AñoKLK']=yesdata['Date'].apply(extractyear1)
yesdata
# Out:
#        Case Number         Date  Year        Type             Country  \
# 0     2016.09.18.c    18-Sep-16  2016  Unprovoked                 USA
# 1     2016.09.18.b    18-Sep-16  2016  Unprovoked                 USA
# 2     2016.09.18.a    18-Sep-16  2016  Unprovoked                 USA
# 3       2016.09.17    17-Sep-16  2016  Unprovoked           AUSTRALIA
# 4       2016.09.15    16-Sep-16  2016  Unprovoked           AUSTRALIA
# ...            ...          ...   ...         ...                 ...
# 5987       ND.0005  Before 1903     0  Unprovoked           AUSTRALIA
# 5988       ND.0004  Before 1903     0  Unprovoked           AUSTRALIA
# 5989       ND.0003    1900-1905     0  Unprovoked                 USA
# 5990       ND.0002    1883-1889     0  Unprovoked              PANAMA
# 5991       ND.0001    1845-1853     0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
#vale, algo es algo!

filtered = yesdata[yesdata['AñoKLK']!=0]
filtered
# Out:
#        Case Number                   Date  Year        Type         Country  \
# 33    2016.07.14.4  Reported  14-Jul-2016  2016  Unprovoked         BAHAMAS
# 34    2016.07.08.R   Reported 08-Jul-2016  2016  Unprovoked           SPAIN
# 85    2016.03.03.R   Reported 03-Mar-2016  2016  Unprovoked       AUSTRALIA
# 88      2016.02.19            19-Feb-2016  2016  Unprovoked   NEW CALEDONIA
# 90    2016.02.10.R   Reported 10-Feb-2016  2016     Invalid  CAYMAN ISLANDS
# ...            ...                    ...   ...         ...             ...
# 5984       ND.0008            Before 1906     0  Unprovoked       AUSTRALIA
# 5985       ND.0007            Before 1906     0  Unprovoked       AUSTRALIA
# 5986       ND.0006            Before 1906     0  Unprovoked       AUSTRALIA
# 5987       ND.0005            Before 1903     0  Unprovoked       AUSTRALIA
# 5988       ND.0004            Before 1903     0  Unprovoked       AUSTRALIA
#
# ...

# %%
filtremos=yesdata[(yesdata['AñoKLK']!=0) & (yesdata['Year']==0)]
filtremos
# Out:
#      Case Number             Date  Year        Type    Country  \
# 5873     ND-0152      Before 2016     0  Unprovoked      KENYA
# 5874     ND-0151  Before Oct-2009     0  Unprovoked     PANAMA
# 5875     ND-0150      Before 1934     0  Unprovoked    URUGUAY
# 5876     ND-0149      Before 1934     0  Unprovoked    URUGUAY
# 5877     ND-0148            2009?     0  Unprovoked        USA
# ...          ...              ...   ...         ...        ...
# 5984     ND.0008      Before 1906     0  Unprovoked  AUSTRALIA
# 5985     ND.0007      Before 1906     0  Unprovoked  AUSTRALIA
# 5986     ND.0006      Before 1906     0  Unprovoked  AUSTRALIA
# 5987     ND.0005      Before 1903     0  Unprovoked  AUSTRALIA
# 5988     ND.0004      Before 1903     0  Unprovoked  AUSTRALIA
#
#                          Area                     Location      Activity  \
# 5873                  Mombasa                    Kilindini        Diving
# ...

# %%
filtremos.loc[5987,'href formula']
#veo que el 'before...' significa que la fecha hace referencia a cuándo el ataque de tiburón se recogió en la literatura
#el año que dan es el año de publicación del escrito que lo recoge
#intentaré suponer que dichos ataques se han producido en el primer año de la década en la que quedan recogidos por la literatura
# Out:
# 'http://sharkattackfile.net/spreadsheets/pdf_directory/ND-0005-RoebuckBay.pdf'

# %%
yesdata['AñoKLK']=yesdata['AñoKLK'].astype('int64')

# %%
#voy a hacer otra función que me realice eso directamente:
def extractyear2(column):
    x=re.findall('\d{4}',column)
    if len(x)==1:
        w=x[0]
        v=w[-1]
        intw=int(w)
        intv=int(v)
        num=intw-intv
        return num
    else: return 0

# %%
yesdata['Añoredondeado']=yesdata['Date'].apply(extractyear2)
yesdata
# Out:
#        Case Number         Date  Year        Type             Country  \
# 0     2016.09.18.c    18-Sep-16  2016  Unprovoked                 USA
# 1     2016.09.18.b    18-Sep-16  2016  Unprovoked                 USA
# 2     2016.09.18.a    18-Sep-16  2016  Unprovoked                 USA
# 3       2016.09.17    17-Sep-16  2016  Unprovoked           AUSTRALIA
# 4       2016.09.15    16-Sep-16  2016  Unprovoked           AUSTRALIA
# ...            ...          ...   ...         ...                 ...
# 5987       ND.0005  Before 1903     0  Unprovoked           AUSTRALIA
# 5988       ND.0004  Before 1903     0  Unprovoked           AUSTRALIA
# 5989       ND.0003    1900-1905     0  Unprovoked                 USA
# 5990       ND.0002    1883-1889     0  Unprovoked              PANAMA
# 5991       ND.0001    1845-1853     0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
yesdata['Año']=yesdata['Añoredondeado'].astype('int64')
yesdata.drop(columns='AñoKLK')
print(hola)
# Out:
#        Case Number         Date  Year        Type             Country  \
# 0     2016.09.18.c    18-Sep-16  2016  Unprovoked                 USA
# 1     2016.09.18.b    18-Sep-16  2016  Unprovoked                 USA
# 2     2016.09.18.a    18-Sep-16  2016  Unprovoked                 USA
# 3       2016.09.17    17-Sep-16  2016  Unprovoked           AUSTRALIA
# 4       2016.09.15    16-Sep-16  2016  Unprovoked           AUSTRALIA
# ...            ...          ...   ...         ...                 ...
# 5987       ND.0005  Before 1903     0  Unprovoked           AUSTRALIA
# 5988       ND.0004  Before 1903     0  Unprovoked           AUSTRALIA
# 5989       ND.0003    1900-1905     0  Unprovoked                 USA
# 5990       ND.0002    1883-1889     0  Unprovoked              PANAMA
# 5991       ND.0001    1845-1853     0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
yesdata=yesdata.drop(columns='Añoredondeado')

# %%
yesdata=yesdata.drop(columns='AñoKLK')

# %%
yesdata.head()
# Out:
#     Case Number       Date  Year        Type    Country      Area  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked        USA   Florida
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked        USA   Florida
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked        USA   Florida
# 3    2016.09.17  17-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
# 4    2016.09.15  16-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location Activity             Name Sex   ...  \
# 0  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 1  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano    M  ...
# 2  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 3                  Thirteenth Beach  Surfing  Rory Angiolella    M  ...
# 4                       Bells Beach  Surfing             male    M  ...
#
#         Investigator or Source                        pdf  \
# 0  Orlando Sentinel, 9/19/2016       2016.09.18.c-NSB.pdf
# ...

# %%
#resituémonos: el objetivo es sustituir ahora el año de quellos sucesos que no tienen año por la nueva fecha estimada
filtremos=yesdata[(yesdata['Año']!=0) & (yesdata['Year']==0)]
# Out:
#      Case Number             Date  Year        Type    Country  \
# 5873     ND-0152      Before 2016     0  Unprovoked      KENYA
# 5874     ND-0151  Before Oct-2009     0  Unprovoked     PANAMA
# 5875     ND-0150      Before 1934     0  Unprovoked    URUGUAY
# 5876     ND-0149      Before 1934     0  Unprovoked    URUGUAY
# 5877     ND-0148            2009?     0  Unprovoked        USA
# ...          ...              ...   ...         ...        ...
# 5984     ND.0008      Before 1906     0  Unprovoked  AUSTRALIA
# 5985     ND.0007      Before 1906     0  Unprovoked  AUSTRALIA
# 5986     ND.0006      Before 1906     0  Unprovoked  AUSTRALIA
# 5987     ND.0005      Before 1903     0  Unprovoked  AUSTRALIA
# 5988     ND.0004      Before 1903     0  Unprovoked  AUSTRALIA
#
#                          Area                     Location      Activity  \
# 5873                  Mombasa                    Kilindini        Diving
# ...

# %%
#dice internet que pruebe con un boolean mask
mask=(yesdata['Año']!=0) & (yesdata['Year']==0)
yesdata['Year'][mask]=yesdata['Año']
yesdata
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#        Case Number         Date  Year        Type             Country  \
# 0     2016.09.18.c    18-Sep-16  2016  Unprovoked                 USA
# 1     2016.09.18.b    18-Sep-16  2016  Unprovoked                 USA
# 2     2016.09.18.a    18-Sep-16  2016  Unprovoked                 USA
# 3       2016.09.17    17-Sep-16  2016  Unprovoked           AUSTRALIA
# 4       2016.09.15    16-Sep-16  2016  Unprovoked           AUSTRALIA
# ...            ...          ...   ...         ...                 ...
# ...

# %%
# Out:
#      Case Number       Date  Year        Type               Country  \
# 0   2016.09.18.c  18-Sep-16  2016  Unprovoked                   USA
# 1   2016.09.18.b  18-Sep-16  2016  Unprovoked                   USA
# 2   2016.09.18.a  18-Sep-16  2016  Unprovoked                   USA
# 3     2016.09.17  17-Sep-16  2016  Unprovoked             AUSTRALIA
# 4     2016.09.15  16-Sep-16  2016  Unprovoked             AUSTRALIA
# ..           ...        ...   ...         ...                   ...
# 95    2016.01.28  28-Jan-16  2016  Unprovoked                   USA
# 96    2016.01.25  25-Jan-16  2016  Unprovoked                   USA
# 97  2016.01.24.b  24-Jan-16  2016  Unprovoked                   USA
# 98  2016.01.24.a  24-Jan-16  2016        Boat  UNITED ARAB EMIRATES
# 99    2016.01.23  23-Jan-16  2016  Unprovoked                   USA
#
#                 Area                          Location         Activity  \
# 0            Florida  New Smyrna Beach, Volusia County          Surfing
# ...

# %%
#he conseguido reducir los Year=0
print((yesdata==0).sum())
# Out:
# Case Number                  0
# Date                         0
# Year                        33
# Type                         0
# Country                      0
# Area                         0
# Location                     0
# Activity                     0
# Name                         0
# Sex                          0
# Age                          0
# Injury                       0
# Fatal (Y/N)                  0
# Time                         0
# Species                      0
# Investigator or Source       0
# pdf                          0
# href formula                 0
# href                         0
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22                  0
# Unnamed: 23                  0
# Año                       4660
# dtype: int64

# %%
#limpio un poco el df:
datos=yesdata[['Case Number','Year','Type','Country','Area','Location','Activity','Name','Sex ','Age','Injury','Fatal (Y/N)','Time','Species ','Investigator or Source','href formula']]

# %%
datos=datos.rename(columns={'Species ': 'Species','Sex ': 'Sex'})

# %%
datos.head()
# Out:
#     Case Number  Year        Type    Country      Area  \
# 0  2016.09.18.c  2016  Unprovoked        USA   Florida
# 1  2016.09.18.b  2016  Unprovoked        USA   Florida
# 2  2016.09.18.a  2016  Unprovoked        USA   Florida
# 3    2016.09.17  2016  Unprovoked  AUSTRALIA  Victoria
# 4    2016.09.15  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location Activity             Name Sex  Age  \
# 0  New Smyrna Beach, Volusia County  Surfing             male   M   16
# 1  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano   M   36
# 2  New Smyrna Beach, Volusia County  Surfing             male   M   43
# 3                  Thirteenth Beach  Surfing  Rory Angiolella   M  NaN
# 4                       Bells Beach  Surfing             male   M  NaN
#
#                                   Injury Fatal (Y/N)   Time    Species  \
# 0                  Minor injury to thigh           N  13h00        NaN
# ...

# %%
#algunas transformaciones que hice a lo loco al principio pero que son rescatables:
def hombres(m):
    if m['Sex']=='lli' or m['Sex']=='M ':
        return 'M'
    else:
        return m
datos=datos.apply(hombres1,axis=1)
datos.head()
# Out:
#     Case Number  Year        Type    Country      Area  \
# 0  2016.09.18.c  2016  Unprovoked        USA   Florida
# 1  2016.09.18.b  2016  Unprovoked        USA   Florida
# 2  2016.09.18.a  2016  Unprovoked        USA   Florida
# 3    2016.09.17  2016  Unprovoked  AUSTRALIA  Victoria
# 4    2016.09.15  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location Activity             Name Sex  Age  \
# 0  New Smyrna Beach, Volusia County  Surfing             male   M   16
# 1  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano   M   36
# 2  New Smyrna Beach, Volusia County  Surfing             male   M   43
# 3                  Thirteenth Beach  Surfing  Rory Angiolella   M  NaN
# 4                       Bells Beach  Surfing             male   M  NaN
#
#                                   Injury Fatal (Y/N)   Time    Species  \
# 0                  Minor injury to thigh           N  13h00        NaN
# ...

# %%
print(set(datos['Country']))
# Out:
# {nan, 'RED SEA', 'SAUDI ARABIA', 'INDONESIA', 'GUYANA', 'MID ATLANTIC OCEAN', 'ST. MARTIN', 'BRITISH VIRGIN ISLANDS', 'THE BALKANS', 'BAHREIN', ' TONGA', 'TUNISIA', 'PUERTO RICO', 'REUNION', 'TAIWAN', 'COOK ISLANDS', 'MEDITERRANEAN SEA', 'NIGERIA', 'COLUMBIA', 'ENGLAND', 'KUWAIT', 'TURKS & CAICOS', 'ANDAMAN / NICOBAR ISLANDAS', 'MALAYSIA', 'NEW CALEDONIA', 'SUDAN?', 'ATLANTIC OCEAN', 'CENTRAL PACIFIC', 'BELIZE', 'Fiji', 'ICELAND', 'CARIBBEAN SEA', 'ECUADOR', 'INDIAN OCEAN?', 'DOMINICAN REPUBLIC', 'ST. MAARTIN', 'PERSIAN GULF', 'ADMIRALTY ISLANDS', 'FRANCE', 'OCEAN', 'GUINEA', 'SOUTH KOREA', 'NORTH ATLANTIC OCEAN', 'RUSSIA', 'NETHERLANDS ANTILLES', 'JAVA', 'MID-PACIFC OCEAN', 'EGYPT', 'MALDIVE ISLANDS', 'COSTA RICA', 'CURACAO', 'MARSHALL ISLANDS', 'NEVIS', 'AZORES', 'SEYCHELLES', 'SAMOA', 'URUGUAY', 'EL SALVADOR', 'BRITISH NEW GUINEA', 'MADAGASCAR', 'PORTUGAL', 'MOZAMBIQUE', 'NEW BRITAIN', 'SOUTH AFRICA', 'DIEGO GARCIA', 'GRAND CAYMAN', 'EGYPT ', 'INDIAN OCEAN', 'BAHAMAS', 'SLOVENIA',
# ...
